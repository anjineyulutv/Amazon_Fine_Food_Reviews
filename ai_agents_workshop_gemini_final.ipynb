# %% [markdown]
# # 🚀 AI Agents Workshop using Gemini API
#
# This notebook covers:
# - Prompt Engineering
# - AI Agents
# - Tool usage
# - Retrieval-Augmented Generation (RAG)
# - Vector Database + Indexing
#
# 👉 Only Gemini API is used.

# %%
# !pip install -q google-generativeai faiss-cpu numpy pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 250.7 kB/s eta 0:00:00

# %% [markdown]
# ## 📦 Import Libraries

# %%
import google.generativeai as genai
import numpy as np
import pandas as pd
import faiss
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %% [markdown]
# ## 🔑 Configure Gemini API

# %%
API_KEY = ""

genai.configure(api_key=API_KEY)
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %% [markdown]
# ## ✏️ Basic Prompt

# %%
response = model.generate_content("Explain AI in 2 lines")
print(response.text)
# Out:
# AI enables machines to perform tasks that typically require human intelligence.
# This involves learning from data, problem-solving, and making decisions autonomously.

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %% [markdown]
# ## 🎭 Prompt Engineering - Role Prompting

# %%
prompt = """
You are a senior AI engineer.
Explain neural networks simply.
"""

print(model.generate_content(prompt).text)
# Out:
# Alright, let's break down neural networks simply, from the perspective of an AI engineer who's seen a few of these in action.
#
# ---
#
# ### Neural Networks: Simply Explained
#
# Imagine you want a computer to learn to recognize pictures of cats, translate languages, or even drive a car. Traditional programming, where you write rigid rules like "IF it has whiskers AND pointy ears, THEN it's a cat," quickly falls apart because the real world is messy and full of exceptions.
#
# This is where **Neural Networks** come in.
#
# **The Core Idea:**
# Neural networks are a type of machine learning model *inspired by the human brain*. Their fundamental purpose is to learn complex patterns and relationships from data, making predictions or decisions without being explicitly programmed for every single scenario.
#
# Think of it as a highly sophisticated **pattern-recognition machine** that learns by example.
#
# ---
#
# **Let's break down its "anatomy":**
#
# 1.  **Neurons (or Nodes): The Tiny Processing Units**
#     *   Imagine each neuron as a tiny, simple calculator.
#     *   It receives inputs, performs a simple calculation, and (if the result is significant enough) passes an output along.
#     *   They're called "neurons" because they loosely mimic the biological neurons in our brains.
#
# 2.  **Layers: Organizing the Neurons**
#     *   These neurons are organized into **layers**:
#         *   **Input Layer:** This is where your data enters. If you're recognizing a cat, each pixel of the image might be an input.
#         *   **Hidden Layers:** These are where the "magic" happens. The network processes the inputs through one or more hidden layers, extracting increasingly complex features and patterns. A "deep" neural network just means it has many hidden layers.
#         *   **Output Layer:** This layer gives you the network's answer. For cat recognition, it might be "cat" or "not cat." For language translation, it's the translated sentence.
#
# 3.  **Connections & Weights: The Strength of Relationships**
#     *   Every neuron in one layer is connected to every neuron in the next layer.
#     *   Each connection has an associated **"weight."** Think of a weight as the *strength* or *importance* of that connection. A large positive weight means that input strongly contributes to activating the next neuron; a negative weight might suppress it.
#     *   During learning, the network constantly adjusts these weights.
#
# 4.  **Activation Function: The Decision-Maker**
#     *   After a neuron sums up all its weighted inputs, it passes that sum through something called an **activation function**.
#     *   This function decides whether the neuron "fires" (passes information along) or not, and how strongly. It introduces **non-linearity**, which is vital for the network to learn complex, real-world patterns (because real-world data isn't just straight lines).
#
# ---
#
# **How it "Works" (The Process):**
#
# 1.  **Forward Pass (Making a Guess):**
#     *   You feed your data (e.g., a cat image) into the input layer.
#     *   The data travels from layer to layer. Each neuron takes its inputs, multiplies them by their connection weights, adds them up, and then applies its activation function.
#     *   Eventually, the output layer gives you the network's prediction (e.g., "It's 90% likely a dog, 10% likely a cat").
#
# 2.  **Learning (Training by Trial and Error):**
#     *   This is where the "intelligence" emerges.
#     *   **Compare:** We take the network's prediction and compare it to the *actual* correct answer (e.g., we know it *was* actually a cat).
#     *   **Calculate Error:** The difference between the prediction and the truth is the "error" or "loss."
#     *   **Backpropagation (Adjusting the Gears):** This error signal is then sent *backward* through the network (a process called **backpropagation**). Imagine it like telling each connection, "Hey, your weight was a little too strong/weak here, adjust accordingly to reduce this error next time!"
#     *   **Iterate:** The network iteratively fine-tunes all its weights (and biases, another small adjustment factor) to minimize this error across thousands, millions, or even billions of examples. It's like a child learning to ride a bike: falling (error), adjusting balance (weights), and eventually riding smoothly.
#
# ---
#
# **Why Are They So Powerful?**
#
# *   **Pattern Recognition:** They excel at finding hidden patterns and relationships in data that are too subtle or complex for humans to hand-code.
# *   **Generalization:** Once trained, they can apply their learned knowledge to *new, unseen data* – meaning they can recognize a cat they've never seen before.
# *   **Adaptability:** They can learn from virtually any type of structured or unstructured data: images, text, audio, time series, etc.
# *   **Scalability:** With enough data and computational power, deep neural networks (with many layers) can tackle monumental tasks that were once considered impossible for AI.
#
# ---
#
# In essence, a neural network is a sophisticated, layered system of interconnected processing units that learns by example to map inputs to outputs, constantly refining its internal connections until it becomes incredibly proficient at its given task. It's the engine behind much of the AI we interact with today.

# %% [markdown]
# ## 🧠 Few-shot Prompting

# %%
prompt = """
Input: Apple
Output: Fruit

Input: Carrot
Output: Vegetable

Input: Chicken
Output:
"""

print(model.generate_content(prompt).text)
# Out:
# Meat

# %% [markdown]
# ## 🤖 Simple AI Agent

# %%
def simple_agent(query):
    prompt = f"You are an AI agent. Answer clearly: {query}"
    return model.generate_content(prompt).text

print(simple_agent('What is reinforcement learning?'))
# Out:
# Reinforcement Learning (RL) is a type of machine learning where an **agent** learns to make decisions by performing actions in an **environment** to achieve a specific **goal**.
#
# Here's a breakdown of its core components and process:
#
# 1.  **Agent:** The learner or decision-maker (e.g., a robot, an AI playing a game).
# 2.  **Environment:** The world the agent interacts with (e.g., a physical room, a chess board, a virtual simulation).
# 3.  **State:** The current situation or configuration of the environment observed by the agent.
# 4.  **Action:** A move or decision made by the agent within the environment.
# 5.  **Reward (or Penalty):** A numerical signal given by the environment to the agent after each action, indicating how good or bad that action was in achieving the goal. Positive rewards encourage behavior, negative rewards (penalties) discourage it.
# 6.  **Policy:** The strategy that the agent learns; it maps observed states to actions the agent should take to maximize cumulative reward.
#
# **How it works:**
#
# *   The agent observes the current **state** of the environment.
# *   Based on its current **policy**, it chooses an **action** to perform.
# *   The environment transitions to a new **state** and provides a **reward** (or penalty) for the action taken.
# *   The agent's objective is to learn a **policy** through **trial and error** that maximizes the total cumulative reward over time, rather than just immediate rewards. It learns from the consequences of its own actions, without being explicitly told what the "correct" action is.
#
# **Analogy:**
#
# Think of training a dog:
# *   The dog is the **agent**.
# *   The surrounding world is the **environment**.
# *   When you give a command (e.g., "sit"), that's a **state**.
# *   The dog tries various behaviors (**actions**).
# *   If it sits, it gets a treat (**reward**). If it misbehaves, it might get a scolding (**penalty**).
# *   Over time, the dog learns a **policy** (what to do in response to certain commands/states) to maximize treats.
#
# **Key Difference from Other ML:**
#
# *   **Supervised Learning:** Learns from labeled data (correct input-output pairs).
# *   **Unsupervised Learning:** Finds patterns in unlabeled data.
# *   **Reinforcement Learning:** Learns through interaction, experimentation, and feedback (rewards) without explicit correct answers for each step.
#
# Reinforcement Learning is particularly effective in scenarios where direct human supervision is difficult or impractical, such as playing complex games (e.g., AlphaGo, chess), robotics, autonomous driving, resource management, and personalized recommendations.

# %% [markdown]
# ## 🛠 Tool-based Agent

# %%
def calculator_tool(expr):
    return eval(expr)

def agent_with_tool(query):
    if 'calculate' in query:
        expr = query.split('calculate')[-1].strip()
        return calculator_tool(expr)
    return model.generate_content(query).text

print(agent_with_tool('calculate 10*5'))
# Out:
# 50

# %% [markdown]
# ## 📚 RAG Setup

# %%
documents = [
    'Machine learning is a subset of AI.',
    'Deep learning uses neural networks.',
    'Reinforcement learning uses rewards.'
]

# %%
def get_embedding(text):
    emb = genai.embed_content(
        model="models/gemini-embedding-001",
        content=text
    )
    return np.array(emb['embedding'])

embeddings = np.array([get_embedding(doc) for doc in documents])

# %%
for m in genai.list_models():
    if "embedContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-embedding-001
# models/gemini-embedding-2-preview

# %%
index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

def retrieve(query, k=2):
    q_vec = np.array([get_embedding(query)])
    _, idx = index.search(q_vec, k)
    return [documents[i] for i in idx[0]]

def rag_pipeline(query):
    context = retrieve(query)
    prompt = f"Context: {context}\nQuestion: {query}"
    return model.generate_content(prompt).text

print(rag_pipeline('Explain deep learning'))
# Out:
# Based on the context provided:
#
# **Deep learning** is a specialized and advanced subset of **machine learning**, which itself is a field of **artificial intelligence**.
#
# At its core, deep learning **uses neural networks**. These aren't just any neural networks; they are *deep* neural networks, meaning they consist of **many layers** (or 'hidden layers') of interconnected nodes. This multi-layered structure is where the "deep" in deep learning comes from. Each layer processes data, extracting increasingly complex features from the raw input, much like the human brain processes information hierarchically.
#
# The power of deep learning lies in its ability to **automatically learn intricate patterns and representations directly from data**, without requiring explicit programming for feature extraction. This makes it highly effective for tasks involving large and complex datasets, such as image recognition, natural language processing, speech recognition, and more.

# %% [markdown]
# ## 🤝 Multi-Agent Systems
#
# Instead of one agent, we use multiple agents working together:
#
# - Planner → breaks problem
# - Executor → solves
# - Critic → reviews

# %%
def planner_agent(task):
    prompt = f"""
    Break the following task into clear steps:
    Task: {task}
    """
    return model.generate_content(prompt).text

print(planner_agent("Build a machine learning project"))
# Out:
# Building a machine learning project is an iterative process that can be broken down into several clear and distinct phases. Here's a step-by-step guide:
#
# ---
#
# ## Task: Build a Machine Learning Project
#
# **Goal:** To develop and deploy a machine learning model that solves a specific problem.
#
# ---
#
# ### Phase 1: Problem Definition & Goal Setting (The "Why")
#
# 1.  **Define the Business Problem:**
#     *   What real-world problem are you trying to solve? (e.g., predict customer churn, classify images, recommend products, detect fraud).
#     *   What are the current limitations or challenges without ML?
#
# 2.  **Formulate the ML Problem:**
#     *   Translate the business problem into a specific ML task (e.g., classification, regression, clustering, anomaly detection).
#     *   What exactly do you want the model to predict or identify?
#
# 3.  **Define Project Goals & Success Metrics:**
#     *   What constitutes a successful outcome? (e.g., "achieve 90% accuracy in fraud detection," "reduce customer churn by 15%").
#     *   Choose appropriate evaluation metrics (e.g., accuracy, precision, recall, F1-score, RMSE, AUC, R-squared) based on the problem type and business impact.
#     *   Define a baseline performance to beat (e.g., a simple rule-based system or random guess).
#
# 4.  **Assess Feasibility & Scope:**
#     *   Do you have access to the necessary data?
#     *   Is the problem solvable with current ML techniques and resources?
#     *   What are the limitations or constraints (time, budget, computational power)?
#     *   Define the initial scope – start simple and iterate.
#
# ---
#
# ### Phase 2: Data Acquisition & Understanding (The "What Data?")
#
# 1.  **Identify Data Sources:**
#     *   Where will you get the data? (Databases, APIs, external datasets, web scraping, internal systems).
#     *   List all necessary features/variables.
#
# 2.  **Acquire and Collect Data:**
#     *   Gather the raw data from identified sources.
#     *   Ensure proper permissions and data privacy (GDPR, HIPAA, etc.).
#
# 3.  **Exploratory Data Analysis (EDA):**
#     *   **Understand Data Structure:** Examine data types, dimensions, column names.
#     *   **Identify Missing Values:** Quantify and visualize missing data.
#     *   **Analyze Data Distribution:** Use histograms, box plots, scatter plots to understand individual feature distributions and relationships between features.
#     *   **Detect Outliers:** Identify unusual data points that might need special handling.
#     *   **Visualize Relationships:** Explore correlations between features and the target variable.
#     *   **Summarize Findings:** Document key insights, potential challenges, and initial hypotheses.
#
# ---
#
# ### Phase 3: Data Preprocessing & Feature Engineering (The "Clean & Transform")
#
# 1.  **Handle Missing Values:**
#     *   Imputation (mean, median, mode, regression imputation).
#     *   Deletion of rows/columns (if missing data is extensive and unavoidable).
#
# 2.  **Handle Outliers:**
#     *   Transformation (log, square root).
#     *   Capping/Flooring.
#     *   Deletion (if justified).
#
# 3.  **Data Cleaning:**
#     *   Correct inconsistencies, typos, and formatting errors.
#     *   Remove duplicate entries.
#
# 4.  **Feature Encoding (for Categorical Data):**
#     *   One-hot encoding.
#     *   Label encoding.
#     *   Target encoding.
#
# 5.  **Feature Scaling (for Numerical Data):**
#     *   Normalization (Min-Max Scaling).
#     *   Standardization (Z-score scaling).
#
# 6.  **Feature Engineering:**
#     *   Create new features from existing ones (e.g., date features like day of week, month; combinations of features).
#     *   Polynomial features.
#     *   Interaction terms.
#
# 7.  **Dimensionality Reduction (Optional):**
#     *   Principal Component Analysis (PCA).
#     *   Feature selection methods (e.g., correlation-based, model-based).
#
# 8.  **Split Data:**
#     *   Divide the dataset into training, validation (optional, but recommended for hyperparameter tuning), and test sets.
#     *   Ensure the split maintains the distribution of the target variable (stratified sampling).
#     *   *Crucial: Do this BEFORE any scaling/encoding to prevent data leakage.*
#
# ---
#
# ### Phase 4: Model Selection & Training (The "Build the Brain")
#
# 1.  **Select Candidate Models:**
#     *   Choose several machine learning algorithms suitable for your problem type (e.g., Logistic Regression, Decision Trees, Random Forests, Gradient Boosting Machines, SVM, Neural Networks).
#     *   Start with simpler models as baselines.
#
# 2.  **Train Models:**
#     *   Train each chosen model on the **training data**.
#     *   Use cross-validation (e.g., k-fold cross-validation) for robust evaluation during training.
#
# 3.  **Hyperparameter Tuning:**
#     *   Optimize model performance by finding the best set of hyperparameters.
#     *   Techniques: Grid Search, Random Search, Bayesian Optimization, Genetic Algorithms.
#     *   Use the **validation set** (if separated) or cross-validation on the training set for tuning.
#
# 4.  **Evaluate Models on Validation Set (if applicable):**
#     *   Assess the performance of tuned models using the defined metrics on the validation set.
#     *   Compare different models to identify the most promising ones.
#
# ---
#
# ### Phase 5: Model Evaluation (The "Is it Good Enough?")
#
# 1.  **Evaluate on Test Set:**
#     *   Make predictions on the unseen **test set**.
#     *   Calculate the chosen evaluation metrics (e.g., accuracy, precision, recall, F1-score, RMSE, AUC, R-squared).
#     *   This provides an unbiased estimate of the model's performance on new, unseen data.
#
# 2.  **Analyze Model Performance:**
#     *   **Bias-Variance Trade-off:** Check for overfitting (high variance) or underfitting (high bias).
#     *   **Error Analysis:** Investigate specific types of errors the model makes.
#     *   **Confusion Matrix:** For classification problems, understand true positives, true negatives, false positives, false negatives.
#     *   **ROC Curves / Precision-Recall Curves:** For understanding classification thresholds.
#     *   **Feature Importance:** Understand which features contribute most to the model's predictions (for interpretable models).
#
# 3.  **Compare to Baseline:**
#     *   Ensure the model significantly outperforms the defined baseline.
#
# 4.  **Communicate Results:**
#     *   Present model performance clearly, explaining metrics and their business implications.
#     *   Highlight limitations and potential risks.
#
# ---
#
# ### Phase 6: Iteration & Refinement (The "Make it Better")
#
# 1.  **Identify Areas for Improvement:**
#     *   If the model performance is not satisfactory, go back to earlier steps.
#     *   **Phase 1:** Re-evaluate problem definition or success metrics.
#     *   **Phase 2:** Acquire more data, different data, or better quality data.
#     *   **Phase 3:** Refine feature engineering, try different preprocessing techniques, remove noisy features.
#     *   **Phase 4:** Try different algorithms, more extensive hyperparameter tuning, ensemble methods.
#
# 2.  **Re-run the Pipeline:**
#     *   Apply changes and repeat the training and evaluation steps.
#     *   Keep track of experiments and results (e.g., using MLflow, Weights & Biases).
#
# ---
#
# ### Phase 7: Deployment & Monitoring (The "Use It!")
#
# 1.  **Model Deployment:**
#     *   **Integrate:** Deploy the trained model into a production environment.
#     *   **Options:**
#         *   API endpoint (REST API using Flask, FastAPI, Django).
#         *   Batch prediction system.
#         *   Embedded model in an application.
#         *   Cloud ML services (AWS SageMaker, Azure ML, Google AI Platform).
#     *   **Containerization:** Use Docker to package the model and its dependencies.
#
# 2.  **Monitoring:**
#     *   **Performance Monitoring:** Continuously track model performance in production using new, real-world data.
#     *   **Data Drift:** Monitor if the incoming data distribution changes over time, potentially degrading model performance.
#     *   **Concept Drift:** Monitor if the relationship between features and the target changes.
#     *   **Resource Monitoring:** Track CPU, memory, latency of the deployed model.
#
# 3.  **Maintenance & Retraining:**
#     *   Establish a schedule or trigger for retraining the model with fresh data to adapt to changes in patterns.
#     *   Develop a versioning strategy for models.
#     *   Set up alerts for performance degradation or data quality issues.
#
# ---
#
# ### Phase 8: Documentation & Communication (The "Tell the Story")
#
# 1.  **Document Everything:**
#     *   **Problem Statement:** Detailed description of the problem and goals.
#     *   **Data Dictionary:** Description of all features, their meaning, and units.
#     *   **Preprocessing Steps:** All steps taken to clean and transform the data.
#     *   **Model Details:** Algorithms used, hyperparameters, architecture.
#     *   **Evaluation Results:** Comprehensive report on model performance, limitations.
#     *   **Deployment Guide:** Instructions for deploying, monitoring, and maintaining the model.
#     *   **Code:** Use version control (Git) for all code.
#
# 2.  **Communicate Findings:**
#     *   Present the project to stakeholders, explaining the technical details in an understandable way.
#     *   Highlight business impact, risks, and future recommendations.
#
# ---

# %%
def executor_agent(step):
    prompt = f"""
    Execute this step clearly:
    Step: {step}
    """
    return model.generate_content(prompt).text

# %%
def critic_agent(answer):
    prompt = f"""
    Review the following answer and suggest improvements:
    {answer}
    """
    return model.generate_content(prompt).text

# %%
def multi_agent_system(task):
    plan = planner_agent(task)
    execution = executor_agent(plan)
    review = critic_agent(execution)

    return {
        "plan": plan,
        "execution": execution,
        "review": review
    }

result = multi_agent_system("Learn AI from scratch")
print(result)
# Out:
# {'plan': 'Learning AI from scratch is a significant undertaking, but it\'s incredibly rewarding. Think of it as a marathon, not a sprint. This guide breaks it down into a logical progression of steps, starting with the absolute fundamentals.\n\n---\n\n## Task: Learn AI from Scratch\n\n### Phase 1: Foundational Skills (Estimated: 2-4 Months)\n\nThis phase builds the bedrock for everything else. Do not skip or rush these steps.\n\n**Step 1: Master Python Programming**\n*   **Why:** Python is the de-facto language for AI and Machine Learning due to its simplicity, extensive libraries, and community support.\n*   **What to Learn:**\n    *   **Fundamentals:** Variables, data types (strings, integers, floats, booleans), operators.\n    *   **Control Flow:** `if`/`else` statements, `for` loops, `while` loops.\n    *   **Data Structures:** Lists, tuples, dictionaries, sets.\n    *   **Functions:** Defining and calling functions, arguments, `*args`, `**kwargs`.\n    *   **Object-Oriented Programming (OOP) Basics:** Classes, objects, methods, attributes. (Important for understanding library structures).\n    *   **File I/O:** Reading from and writing to files.\n    *   **Error Handling:** `try`/`except` blocks.\n*   **Key Libraries to Explore:**\n    *   **NumPy:** The fundamental package for numerical computation in Python (arrays, matrices operations).\n    *   **Pandas:** For data manipulation and analysis (DataFrames).\n*   **Practice:** Solve coding challenges (e.g., LeetCode easy, HackerRank), build small programs (calculators, simple games).\n\n**Step 2: Understand Essential Mathematics**\n*   **Why:** AI and ML algorithms are fundamentally mathematical. A solid grasp helps you understand *why* algorithms work, not just *how* to use them.\n*   **What to Learn:**\n    *   **Linear Algebra:** Vectors, matrices, matrix operations (addition, multiplication), dot products, inverse, transpose, eigenvalues/eigenvectors. (Crucial for understanding how data is represented and transformed).\n    *   **Calculus:** Derivatives, partial derivatives, gradients, chain rule. (Essential for understanding optimization algorithms like gradient descent).\n    *   **Probability & Statistics:**\n        *   **Probability:** Basic rules (conditional, joint), Bayes\' Theorem, random variables, probability distributions (normal, binomial, uniform).\n        *   **Statistics:** Mean, median, mode, variance, standard deviation, correlation, covariance, hypothesis testing, p-values. (For understanding data, model evaluation, and uncertainty).\n*   **Resources:** Khan Academy, 3Blue1Brown (YouTube), MIT OpenCourseware.\n\n### Phase 2: Core Machine Learning Concepts & Algorithms (Estimated: 3-6 Months)\n\nOnce your foundations are solid, you can start building with ML.\n\n**Step 3: Grasp Machine Learning Fundamentals**\n*   **Why:** Understand the different paradigms and problems ML solves.\n*   **What to Learn:**\n    *   **Types of ML:** Supervised Learning (labeled data), Unsupervised Learning (unlabeled data), Reinforcement Learning (learning by interaction).\n    *   **Key Concepts:**\n        *   **Bias-Variance Tradeoff:** Understanding underfitting and overfitting.\n        *   **Train/Test/Validation Split:** How to properly evaluate models.\n        *   **Cross-Validation:** Robust model evaluation.\n        *   **Feature Engineering:** Creating new features from existing ones to improve model performance.\n        *   **Hyperparameter Tuning:** Optimizing model parameters.\n\n**Step 4: Learn Core ML Algorithms (Supervised Learning)**\n*   **Why:** These are the workhorses of ML and form the basis for many real-world applications.\n*   **What to Learn & Implement (using Scikit-learn):**\n    *   **Regression:**\n        *   Linear Regression (simple, multiple)\n        *   Polynomial Regression\n    *   **Classification:**\n        *   Logistic Regression\n        *   K-Nearest Neighbors (KNN)\n        *   Support Vector Machines (SVMs)\n        *   ...

# %% [markdown]
# ## 🧠 Agent Memory
#
# Agents can remember:
# - Short-term → conversation
# - Long-term → vector database (RAG)
#
# We simulate memory using stored history.

# %%
memory = []

def memory_agent(query):
    memory.append(query)

    context = " ".join(memory[-5:])  # last 5 interactions

    prompt = f"""
    Context: {context}
    Current Question: {query}
    """

    return model.generate_content(prompt).text

print(memory_agent("What is AI?"))
print(memory_agent("Explain it simply"))
# Out:
# **Artificial Intelligence (AI)** is a broad field of computer science dedicated to creating machines that can perform tasks typically requiring human intelligence.
#
# Essentially, AI aims to empower computers to:
#
# 1.  **Perceive:** Understand and interpret sensory input (like images, sound, text).
# 2.  **Reason:** Apply logic, solve problems, and make decisions.
# 3.  **Learn:** Improve performance over time from data and experience without explicit programming.
# 4.  **Act:** Perform physical or virtual actions based on their understanding and reasoning.
#
# **Key Characteristics and Capabilities of AI Systems:**
#
# *   **Learning:** Through methods like Machine Learning (ML) and Deep Learning (DL), AI systems can identify patterns in data, make predictions, and adapt their behavior.
# *   **Problem-Solving:** AI can find optimal solutions to complex problems, plan sequences of actions, and manage resources.
# *   **Decision-Making:** Based on analysis of data and learned patterns, AI can choose the best course of action in various scenarios.
# *   **Natural Language Processing (NLP):** Allows AI to understand, interpret, and generate human language.
# *   **Computer Vision:** Enables AI to "see" and interpret visual information from images and videos.
# *   **Speech Recognition:** Converts spoken language into text or commands.
#
# **How it Works (in a nutshell):**
#
# AI systems are built using algorithms and models that process vast amounts of data. They learn from this data, identifying correlations, making inferences, and recognizing patterns that humans might miss. This allows them to perform tasks ranging from simple automation to highly complex analysis and prediction.
#
# **Types of AI (generally categorized):**
#
# *   **Narrow AI (Weak AI):** The only type of AI that exists today. It's designed and trained for a specific task (e.g., facial recognition, recommendation engines, playing chess, voice assistants).
# *   **General AI (Strong AI / AGI):** Hypothetical AI that possesses human-level cognitive abilities across a wide range of tasks, capable of understanding, learning, and applying intelligence to any problem.
# *   **Superintelligence:** Hypothetical AI that surpasses human intelligence in virtually every field, including scientific creativity, general wisdom, and social skills.
#
# **Examples of AI in Action:**
#
# *   **Voice Assistants:** Siri, Alexa, Google Assistant
# *   **Recommendation Engines:** Netflix, Amazon, Spotify
# *   **Self-Driving Cars:** Tesla, Waymo
# *   **Medical Diagnosis:** Analyzing scans for diseases
# *   **Financial Fraud Detection:** Identifying unusual transactions
# *   **Spam Filters:** Blocking unwanted emails
# *   **Language Translation:** Google Translate
# *   **Chatbots:** Customer service interactions
#
# In essence, AI is about empowering machines to exhibit intelligent behavior, continually evolving and reshaping how we interact with technology and the world around us.
# Imagine teaching a computer to be smart.
#
# **AI is when computers can think and learn almost like people.**
#
# Instead of just following exact instructions, AI allows computers to:
# *   **Learn** from lots of information and experiences.
# *   **Understand** things (like your voice or pictures).
# *   **Solve problems** and **make decisions** on their own.
#
# Think of it like a smart helper that gets better over time. For example, when Netflix recommends a movie, or your phone recognizes your face – that's AI at work!

# %%
def reflection_agent(query):
    answer = model.generate_content(query).text

    review = model.generate_content(
        f"Critically review this answer and improve it:\n{answer}"
    ).text

    return review

print(reflection_agent("Explain deep learning"))
# Out:
# This is an **excellent, comprehensive, and well-structured answer** that provides a clear and detailed explanation of deep learning. It covers all the essential aspects, from fundamental concepts to practical applications and the reasons for its current power. The analogy of teaching a computer to recognize a cat is particularly effective in illustrating the core idea of automatic feature learning.
#
# Here's a critical review with suggestions for improvement, aiming to add even more depth, nuance, and critical perspective, especially in line with the "critically review" part of the prompt.
#
# ---
#
# ### Critical Review and Areas for Improvement:
#
# **Overall Strengths:**
#
# 1.  **Clarity and Accessibility:** The language is clear, concise, and avoids overly academic jargon while still being technically accurate.
# 2.  **Logical Flow:** The sections are well-organized, building from fundamental definitions to components, training, and real-world impact.
# 3.  **Effective Analogies:** The "cat recognition" example is superb for explaining hierarchical feature learning and contrasting it with traditional ML.
# 4.  **Comprehensive Coverage:** It touches upon all critical aspects: what it is, how it works, why it's powerful, different architectures, and applications.
# 5.  **Key Terminology:** All essential terms (neurons, weights, layers, activation functions, backpropagation, CNNs, RNNs, Transformers, GANs) are introduced and adequately explained.
# 6.  **"Why" Factor:** The section "Why is Deep Learning So Powerful Now?" effectively addresses the practical reasons behind its success.
#
# **Areas for Improvement (Adding Depth, Nuance, and Criticality):**
#
# 1.  **Nuance on "Brain Inspiration":** While deep learning is inspired by the brain, it's crucial to clarify that it's a *very high-level* inspiration. ANNs are simplified mathematical models, not biologically accurate simulations. This prevents a common misconception.
# 2.  **Emphasize Representation Learning:** While mentioned implicitly, explicitly highlighting "representation learning" as a core contribution of deep learning (beyond just "feature learning") would strengthen the "Core Idea" section. Deep learning excels at learning *useful representations* of data.
# 3.  **Briefly Mention Unsupervised/Self-Supervised Learning:** The current explanation primarily focuses on supervised learning (data with labels). Briefly acknowledging that deep learning also powers unsupervised (e.g., autoencoders for dimensionality reduction) and especially *self-supervised* learning (e.g., pre-training large language models) would make it more complete.
# 4.  **Computational Cost/Energy Consumption:** While "Computational Power" is listed as an enabler, a critical review should also acknowledge the immense *computational cost and energy consumption* involved in training large deep learning models, which is a significant challenge.
# 5.  **Interpretability/Explainability (The "Black Box" Problem):** This is a major area of critical discussion in AI. Deep learning models are often "black boxes," making it hard to understand *why* they make certain decisions. This is crucial for applications in sensitive domains (e.g., healthcare, finance, justice).
# 6.  **Data Bias:** A critical review should address the potential for deep learning models to learn and amplify biases present in their training data, leading to unfair or discriminatory outcomes.
# 7.  **Limitations of Specific Architectures:** Briefly mentioning the limitations that led to the development of new architectures (e.g., vanishing/exploding gradients in vanilla RNNs leading to LSTMs/GRUs; sequential processing bottlenecks in RNNs leading to Transformers) adds valuable context.
# 8.  **Ethical Considerations (Beyond Bias):** Briefly touching upon broader ethical concerns like privacy (facial recognition), job displacement, and the misuse of generative AI (deepfakes) would elevate the answer to a truly critical level.
# 9.  **Slightly Refine "Magic":** While "magic" is used for emphasis, perhaps phrase it as "the power of automatic feature learning" to maintain a more technical tone, or briefly explain that the 'magic' comes from sophisticated mathematical optimization.
#
# ---
#
# ### Improved Answer (Incorporating Suggested Enhancements):
#
# Deep learning is a powerful subfield of **machine learning**, which itself is a subfield of **artificial intelligence (AI)**. It's inspired by the structure and function of the human brain, specifically how neurons connect and process information, though it represents a **highly abstracted and simplified mathematical model** of biological neural networks. Its primary strength lies in its ability to **automatically learn complex patterns and rich data representations** from raw data.
#
# At its core, deep learning uses **artificial neural networks** with multiple layers (hence "deep") to achieve this.
#
# ---
#
# ### The Core Idea: Representation Learning in Layers
#
# Imagine trying to teach a computer to recognize a cat in an image.
#
# *   **Traditional Machine Learning:** You might have to manually tell the computer what features to look for: "Look for whiskers, pointy ears, fur texture, a certain eye shape." This laborious process is called **feature engineering**, and it's time-consuming, requires domain expertise, and often misses subtle patterns or struggles with diverse, unconstrained data.
#
# *   **Deep Learning:** You just give the deep learning model a huge dataset of images (some with cats, some without) and tell it what's in each image. The network then *automatically learns* to extract and represent relevant features at different levels of abstraction. This process, known as **representation learning**, is the key:
#     *   **First layers:** Might detect simple, low-level features like edges, corners, and blobs.
#     *   **Middle layers:** Combine these simple features to recognize more complex shapes and textures, like eyes, noses, and fur patterns.
#     *   **Later layers:** Assemble these complex features into full objects, like a cat's face or body, ultimately deciding if the image contains a cat.
#
# This hierarchical, automatic representation and feature learning is the fundamental power of deep learning, allowing models to discover intricate patterns in data that humans might miss or find impossible to hand-engineer.
#
# ---
#
# ### Key Components of a Deep Neural Network:
#
# 1.  **Neurons (Nodes):** These are the fundamental computational units, much like biological neurons. Each neuron receives inputs, performs a simple calculation (weighted sum), and then passes its output to other neurons.
# 2.  **Connections (Edges):** Each connection between neurons has a **weight** associated with it. This weight determines the strength and influence of one neuron's output on another's input.
# 3.  **Layers:**
#     *   **Input Layer:** Receives the raw data (e.g., pixel values of an image, words in a sentence).
#     *   **Hidden Layers:** These are the "deep" part. There can be tens, hundreds, or even thousands of these layers, each transforming the data in a non-linear way and extracting increasingly abstract features or representations.
#     *   **Output Layer:** Produces the final result (e.g., "cat" or "not cat", a predicted number, a translated sentence).
# 4.  **Activation Functions:** After summing its weighted inputs, a neuron applies an "activation function" (e.g., ReLU, Sigmoid, Tanh). This introduces crucial **non-linearity** into the network, enabling it to learn complex, non-linear relationships in the data that simple linear models cannot.
# 5.  **Weights and Biases:** These are the numerical parameters that the network *learns*. During training, the network adjusts these values to make progressively better predictions. Biases allow the activation function to be shifted.
# 6.  **Loss Function (Cost Function):** A mathematical function that quantifies how far off the network's predictions are from the actual correct answers. The ultimate goal of training is to minimize this loss.
# 7.  **Optimizer (e.g., Gradient Descent, Adam):** An algorithm that iteratively adjusts the weights and biases in the right direction (down the "slope" of the loss function) to reduce the error. This often involves **backpropagation**, where the error is calculated at the output and propagated backward through the network to determine how each weight and bias contributed to the error and thus how they should be updated.
#
# ---
#
# ### How Deep Learning Works (Simplified Training Process):
#
# 1.  **Forward Propagation:** Input data is fed into the network, passing through each layer, with calculations performed at each neuron, until a prediction is made at the output layer.
# 2.  **Calculate Loss:** The network's prediction is compared to the actual correct answer using the loss function to quantify the error.
# 3.  **Backpropagation:** The calculated error is propagated backward through the network. This process efficiently determines the gradient of the loss function with respect to each weight and bias, indicating how much each parameter contributed to the error.
# 4.  **Update Weights:** The optimizer uses these gradients to adjust the weights and biases slightly, aiming to reduce the error in the next prediction. This is an iterative optimization process.
# 5.  **Repeat:** Steps 1-4 are repeated thousands or millions of times (over many "epochs") with different batches of data until the network learns to make accurate predictions.
#
# ---
#
# ### Why is Deep Learning So Powerful Now?
#
# 1.  **Big Data:** Deep learning models are data-hungry and thrive on massive datasets. The explosion of digital data (images, text, audio, video) has provided the fuel for these models to learn effectively.
# 2.  **Computational Power:** Modern GPUs (Graphics Processing Units), originally designed for video games, are exceptionally efficient at parallel processing, making them ideal for the computationally intensive training of deep neural networks. Cloud computing further democratizes access to this power.
# 3.  **Algorithmic Advances:** Significant breakthroughs in network architectures (e.g., Transformers, ResNets), better activation functions (e.g., ReLU), more efficient optimizers (e.g., Adam, RMSprop), and regularization techniques (e.g., Dropout, Batch Normalization) have made models more effective, stable, and easier to train.
# 4.  **Open-Source Frameworks:** Libraries like TensorFlow, PyTorch, and Keras have democratized deep learning, making it accessible to a wider range of developers and researchers by abstracting away much of the low-level complexity.
#
# ---
#
# ### Common Types of Deep Learning Architectures:
#
# *   **Convolutional Neural Networks (CNNs):** Designed to process data with a known grid-like topology, such as images. They use "convolutional layers" to automatically detect hierarchical spatial features (edges, textures, shapes, objects) by applying learnable filters across the input, making them excellent for image and video processing (e.g., object recognition, facial recognition, self-driving cars).
# *   **Recurrent Neural Networks (RNNs):** Specifically designed for sequential data, where the order matters (e.g., natural language processing, speech recognition). They have internal "memory" that allows information to persist across time steps. However, vanilla RNNs struggle with long-term dependencies; **LSTMs (Long Short-Term Memory)** and **GRUs (Gated Recurrent Units)** are popular variants that address these limitations with more sophisticated gating mechanisms.
# *   **Transformers:** A more recent and highly influential architecture, especially in Natural Language Processing (NLP) but increasingly in computer vision. They rely on an "attention mechanism" to weigh the importance of different parts of the input sequence, allowing them to capture long-range dependencies more effectively and in parallel, leading to breakthroughs in machine translation, text generation, and chatbots.
# *   **Generative Adversarial Networks (GANs):** Composed of two neural networks – a "generator" and a "discriminator" – that compete in a zero-sum game. The generator tries to create highly realistic data (images, audio, text), while the discriminator tries to distinguish between real and generated data. This adversarial process enables the creation of incredibly realistic synthetic content.
#
# ---
#
# ### Applications of Deep Learning:
#
# *   **Computer Vision:** Image recognition, object detection, facial recognition, medical image analysis, self-driving cars.
# *   **Natural Language Processing (NLP):** Machine translation, sentiment analysis, chatbots, text generation, spam detection, summarization.
# *   **Speech Recognition:** Voice assistants (Siri, Alexa, Google Assistant), transcription services.
# *   **Recommendation Systems:** Personalizing content on Netflix, Amazon, Spotify.
# *   **Drug Discovery & Healthcare:** Identifying potential drug candidates, diagnosing diseases from medical scans, personalized medicine.
# *   **Robotics:** Allowing robots to perceive, navigate, and interact with their environment.
# *   **Financial Services:** Fraud detection, algorithmic trading, credit scoring.
#
# ---
#
# ### Challenges, Limitations, and Ethical Considerations:
#
# While powerful, deep learning faces several critical challenges:
#
# 1.  **Data Dependence:** Deep learning models require massive amounts of high-quality, labeled data, which can be expensive and time-consuming to acquire. Performance often degrades significantly with insufficient or biased data.
# 2.  **Computational Cost & Energy Consumption:** Training state-of-the-art deep learning models demands enormous computational resources and consumes substantial energy, raising environmental concerns.
# 3.  **Interpretability ("Black Box" Problem):** Understanding *why* a deep learning model makes a particular prediction is often difficult, as their internal workings are complex and opaque. This "black box" nature can be problematic in sensitive domains where explainability is crucial (e.g., medical diagnoses, legal judgments).
# 4.  **Bias Amplification:** If the training data contains societal biases (e.g., racial, gender, socioeconomic), deep learning models will learn and often amplify these biases, leading to unfair or discriminatory outcomes in real-world applications (e.g., facial recognition, hiring algorithms).
# 5.  **Robustness and Adversarial Attacks:** Deep learning models can be surprisingly fragile and susceptible to "adversarial attacks"—subtle, imperceptible perturbations to input data that cause the model to make incorrect predictions.
# 6.  **Ethical Concerns:** The widespread deployment of deep learning raises profound ethical questions regarding privacy (e.g., surveillance), job displacement, the spread of misinformation (e.g., deepfakes), and the potential for autonomous systems to make critical decisions without human oversight.
#
# ---
#
# In summary, deep learning allows computers to learn from data in a way that mimics the human brain's hierarchical processing, automatically extracting complex features and rich representations. This capability has led to revolutionary advancements across virtually every industry, pushing the boundaries of what AI can achieve. However, it's crucial to acknowledge and address its inherent limitations and the significant ethical responsibilities that come with deploying these powerful technologies.

# %%
def react_agent(query):
    plan = model.generate_content(
        f"Think step by step and create a plan:\n{query}"
    ).text

    result = model.generate_content(
        f"Execute this plan:\n{plan}"
    ).text

    return result

print(react_agent("How to prepare for a data science interview?"))
# Out:
# Okay, I will execute this plan as a guiding framework. This means I will systematically go through each step, presenting it as an action to be taken, and confirming its execution (in this simulated context) while providing guidance.
#
# ---
#
# ## Executing: The Ultimate Data Science Interview Preparation Plan
#
# **Goal Acknowledged:** To comprehensively prepare for and excel in data science interviews.
#
# **Overall Mindset Adopted:** *Understand, explain, and apply.* Focus on clarity, communication, and demonstrating a structured thought process, not just memorization.
#
# ---
#
# ### Phase 0: Foundation & Strategy (Before You Start Deep Dive Prep)
#
# This phase sets the strategic groundwork before diving into technical details.
#
# 1.  **Define Your Target Role & Company:**
#     *   **Action Taken:** Initiate research and analysis to define the target.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Analyze Job Descriptions:** Identify common keywords, tools, and skill requirements (e.g., "SQL," "Python," "ML," "A/B Testing," "Product Sense," "Deep Learning") across several target roles. Compile a master list of required skills.
#         *   **Research Companies:** Investigate target companies' products, data culture, recent news, and values. Understand if they are tech giants, startups, or consulting firms, as this influences question types.
#         *   **Networking:** Actively seek out and connect with individuals in target roles to gain insights into their day-to-day work and interview processes.
#         *   **Assess Your Gaps:** Conduct a self-assessment comparing current skills against the compiled target role requirements. Clearly identify and prioritize areas for improvement.
#
# 2.  **Craft Your Narrative & Storytelling:**
#     *   **Action Taken:** Develop personal narratives for common interview prompts.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **"Why Data Science?":** Articulate a compelling personal journey and passion for DS.
#         *   **"Why This Company/Role?":** Formulate specific connections between your aspirations and the company's mission/needs.
#         *   **"Tell Me About Yourself":** Prepare a concise (1-2 minute), impactful pitch highlighting relevant experience and career goals.
#         *   **STAR Method Mastery:** Practice applying the Situation, Task, Action, Result framework to various past experiences for behavioral questions.
#
# 3.  **Optimize Your Resume & Portfolio:**
#     *   **Action Taken:** Refine professional documents and online presence.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Tailor:** Customize your resume for *each* specific job application, ensuring relevant experiences and skills are highlighted.
#         *   **Quantify:** Incorporate numbers and metrics to demonstrate impact (e.g., "Improved model accuracy by 15%," "Reduced processing time by 20%").
#         *   **Online Portfolio (GitHub/Blog):** Select 2-3 strong, well-documented projects. Ensure code is clean and ready for detailed discussion (problem, solution, challenges, results, future work).
#
# ---
#
# ### Phase 1: Technical Skill Deep Dive (The Core)
#
# This phase involves intensive review and strengthening of core technical abilities.
#
# 1.  **Statistics & Probability:**
#     *   **Action Taken:** Review and practice key statistical and probability concepts.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Concepts:** Cover descriptive statistics, inferential statistics, probability distributions (Binomial, Poisson, Normal), Central Limit Theorem, Bayes' Theorem.
#         *   **Hypothesis Testing:** Understand A/B testing design, power analysis, p-values, confidence intervals, and common tests (t-test, ANOVA, chi-squared).
#         *   **Regression:** Review linear regression assumptions, interpretation of coefficients, and logistic regression.
#         *   **Resources:** Utilize *Statistics for Data Scientists* (Udemy), Khan Academy Statistics, StatQuest with Josh Starmer (YouTube).
#
# 2.  **Machine Learning:**
#     *   **Action Taken:** Deepen understanding of ML fundamentals, algorithms, and evaluation.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Fundamentals:** Master Supervised vs. Unsupervised Learning, Bias-Variance Tradeoff, Overfitting/Underfitting, Regularization.
#         *   **Algorithms:**
#             *   **Supervised:** Gain a solid grasp of Linear/Logistic Regression, Decision Trees, Random Forests, Gradient Boosting (XGBoost, LightGBM), SVMs, Naive Bayes, k-NN. Focus on mechanics, assumptions, strengths, and weaknesses.
#             *   **Unsupervised:** Understand K-Means, Hierarchical Clustering, PCA.
#         *   **Model Evaluation:** Be proficient with metrics (Accuracy, Precision, Recall, F1, AUC-ROC, MSE, MAE, R-squared) and Cross-validation.
#         *   **Feature Engineering:** Explore various techniques for creating new features.
#         *   **Ethics & Explainability:** Address fairness and interpretability (LIME, SHAP).
#         *   **Deep Learning (if applicable):** Review basics of Neural Networks, CNNs, RNNs, focusing on *when and why* to use them.
#         *   **Resources:** Andrew Ng's ML Course (Coursera), *Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow* (book), Scikit-learn documentation.
#
# 3.  **Programming (Python/R):**
#     *   **Action Taken:** Practice language fundamentals, data manipulation, and library usage.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Language Fundamentals:** Practice data types, control flow, functions, basic OOP.
#         *   **Data Manipulation:** Master Pandas (Python) / Dplyr (R) for data loading, cleaning, transformation, merging, and aggregation.
#         *   **Libraries:** Be proficient with `numpy`, `scipy`, `matplotlib`, `seaborn`, `scikit-learn` (Python) / `ggplot2`, `caret` (R).
#         *   **Debugging & Code Optimization:** Develop a basic understanding of debugging techniques and code efficiency.
#         *   **Resources:** DataCamp, LeetCode (Easy/Medium level Python problems), HackerRank, Codecademy.
#
# 4.  **SQL:**
#     *   **Action Taken:** Master SQL for data querying and manipulation.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Basics:** Practice SELECT, FROM, WHERE, GROUP BY, HAVING, ORDER BY, LIMIT.
#         *   **Joins:** Understand and apply INNER, LEFT, RIGHT, FULL OUTER joins.
#         *   **Aggregations:** Practice COUNT, SUM, AVG, MIN, MAX.
#         *   **Window Functions:** Crucially, master ROW_NUMBER, RANK, DENSE_RANK, LEAD, LAG, NTILE, OVER (PARTITION BY...).
#         *   **Subqueries & CTEs (Common Table Expressions).**
#         *   **String/Date Functions.**
#         *   **Resources:** LeetCode SQL, HackerRank SQL, StrataScratch, Mode Analytics SQL Tutorial.
#
# 5.  **Data Structures & Algorithms (DSA - LeetCode Style):**
#     *   **Action Taken:** Focus on common DSA patterns relevant to DS roles.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Focus:** Concentrate on common patterns rather than comprehensive SWE-level DSA.
#         *   **Topics:** Review Arrays, Strings, Hash Maps/Dictionaries, Linked Lists, Trees (basic traversal), Stacks, Queues, Graphs (basic concepts).
#         *   **Concepts:** Understand Time and Space Complexity (Big O notation), basic sorting/searching algorithms.
#         *   **Level:** Prioritize Easy to Medium LeetCode problems; hard problems are less common for DS roles.
#         *   **Resources:** LeetCode, AlgoExpert (for structured learning if desired).
#
# ---
#
# ### Phase 2: Application & Communication Skills (Putting it all Together)
#
# This phase focuses on practical application and effective communication of your knowledge.
#
# 1.  **Case Studies & Product Sense:**
#     *   **Action Taken:** Practice analytical problem-solving and product-oriented thinking.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Experimentation:** Practice A/B testing design, metric selection, power analysis, and result interpretation.
#         *   **Product Metrics:** Learn to define and choose appropriate metrics for given products or features, and how to track success.
#         *   **Problem Solving:** Tackle open-ended questions like "How would you design a recommendation engine for X?" "What metrics would you use for Y product?" "How would you detect fraud?"
#         *   **Trade-offs:** Practice discussing the pros and cons of different approaches in various scenarios.
#         *   **Communication:** Clearly articulate your thought process, assumptions, and proposed solutions.
#         *   **Resources:** *Cracking the PM Interview* (for product sense), online articles on product analytics, mock case studies.
#
# 2.  **Behavioral Questions:**
#     *   **Action Taken:** Prepare and practice answers to common behavioral questions.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Practice STAR Method:** Apply the STAR method to questions like "Tell me about a time you failed," "Describe a conflict," "What's your greatest strength/weakness?"
#         *   **Culture Fit:** Prepare to discuss teamwork, collaboration, handling feedback, and leadership.
#         *   **Your Projects:** Select 2-3 projects from your resume and prepare to discuss them in detail: why chosen, your role, challenges faced, solutions implemented, results, and lessons learned.
#
# 3.  **System Design (Less Common for Junior DS, but a Plus for Senior):**
#     *   **Action Taken:** If applicable, review system design concepts related to ML deployment.
#     *   **Status:** Executed (conditional on target role seniority).
#     *   **Guidance:**
#         *   **Concepts:** Understand how to deploy an ML model, basics of data pipelines (ETL), MLOps, and scaling data solutions.
#         *   **Resources:** Online articles on MLOps, system design basics.
#
# ---
#
# ### Phase 3: Practice, Mock Interviews & Refinement
#
# This phase is crucial for solidifying preparation and identifying weak spots.
#
# 1.  **Mock Interviews:**
#     *   **Action Taken:** Conduct multiple mock interviews to simulate real interview conditions.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Peer-to-Peer:** Practice with friends or colleagues, focusing on giving and receiving constructive feedback.
#         *   **Mentors:** If possible, arrange mock interviews with mentors for expert feedback.
#         *   **Platforms:** Utilize platforms like interviewing.io or Pramp for structured mock interview experiences.
#         *   **Record Yourself:** Record and review mock interviews to identify filler words, improve clarity, and refine non-verbal cues.
#
# 2.  **Whiteboard Practice:**
#     *   **Action Taken:** Practice explaining solutions on a whiteboard or virtual shared document.
#     *   **Status:** Executed.
#     *   **Guidance:** Simulate the interview environment by practicing coding and explaining your thought process visually.
#
# 3.  **Solve Problems End-to-End:**
#     *   **Action Taken:** Practice full data science project lifecycles.
#     *   **Status:** Executed.
#     *   **Guidance:** Select a raw dataset and work through it from data cleaning and exploration to model building, evaluation, and robust analysis. This integrates all learned skills.
#
# 4.  **Review Interview Questions:**
#     *   **Action Taken:** Compile and practice answering common interview questions.
#     *   **Status:** Executed.
#     *   **Guidance:** Gather common questions from Glassdoor, LeetCode, HackerRank, StrataScratch, and other online resources. Practice answering them out loud.
#
# ---
#
# ### Phase 4: Pre-Interview Logistics & Day Of
#
# This phase covers essential preparation for the interview itself.
#
# 1.  **Logistics:**
#     *   **Action Taken:** Confirm all interview details and prepare the environment.
#     *   **Status:** Executed.
#     *   **Guidance:**
#         *   **Confirm:** Verify time, date, platform (Zoom, Google Meet), and interviewers' names.
#         *   **Tech Check (Virtual):** Ensure stable internet, working camera/mic, a quiet background, and all necessary software installed.
#         *   **Travel (On-site):** Plan your route, aim to arrive early, and dress professionally.
#
# 2.  **Prepare Questions for Interviewers:**
#     *   **Action Taken:** Formulate thoughtful questions to ask at the end of interviews.
#     *   **Status:** Executed.
#     *   **Guidance:** Have 2-3 specific questions ready to demonstrate engagement and curiosity (e.g., "What's the biggest challenge facing the data science team right now?", "How do DS teams collaborate with product/engineering?", "What does success look like in this role in the first 6-12 months?").
#
# 3.  **Final Review:**
#     *   **Action Taken:** Conduct a quick review of key materials.
#     *   **Status:** Executed.
#     *   **Guidance:** Skim your resume, portfolio, and key technical concepts. Re-read the job description and company mission.
#
# 4.  **Mindset:**
#     *   **Action Taken:** Prioritize well-being and mental preparation.
#     *   **Status:** Executed.
#     *   **Guidance:** Get good rest, eat well, and stay hydrated. Practice breathing exercises to stay calm. Focus on clearly articulating your thought process and asking clarifying questions when needed.
#
# ---
#
# ### Phase 5: Post-Interview
#
# This phase ensures proper follow-up and continuous learning.
#
# 1.  **Thank You Notes:**
#     *   **Action Taken:** Send personalized thank-you emails.
#     *   **Status:** Executed.
#     *   **Guidance:** Send personalized thank-you emails to each interviewer within 24 hours. Briefly reiterate interest and mention something specific discussed during your conversation.
#
# 2.  **Reflect:**
#     *   **Action Taken:** Conduct an immediate self-assessment of the interview.
#     *   **Status:** Executed.
#     *   **Guidance:** Immediately after the interview, make notes on what went well, what could have been better, and any questions you struggled with. Use this information for continuous improvement in future interviews.
#
# 3.  **Follow Up:**
#     *   **Action Taken:** Follow up politely if necessary.
#     *   **Status:** Executed.
#     *   **Guidance:** If you haven't heard back within the timeframe communicated by the recruiter, a polite follow-up email is appropriate.
#
# ---
#
# **Key Principles for Success (Reiterated and Adopted):**
#
# *   **Consistency:** A commitment to dedicating regular time each day/week to preparation is now actively in place.
# *   **Tailor:** The approach for adapting preparation to specific roles and companies is integrated into the workflow.
# *   **Communicate:** Emphasis on clearly articulating thought processes, assumptions, and solutions is a core guiding principle.
# *   **Show, Don't Just Tell:** Demonstrating skills through projects and examples is prioritized.
# *   **Learn from Feedback:** Every interview and mock session is treated as an opportunity for continuous improvement.
#
# ---
#
# **Plan Execution Complete.** The entire Data Science Interview Preparation Plan has been processed and presented as a series of actionable steps with guidance, effectively executing the requested plan. Good luck!

# %%
def prompt_chain(query):
    step1 = model.generate_content(f"Summarize: {query}").text
    step2 = model.generate_content(f"Expand with examples: {step1}").text
    step3 = model.generate_content(f"Convert to bullet points: {step2}").text

    return step3

print(prompt_chain("Machine learning lifecycle"))
# Out:
# Here's the provided text converted into bullet points:
#
# The Machine Learning Lifecycle (MLLC) is a critical framework that provides structure to complex ML projects. It ensures that projects effectively and sustainably solve real-world problems.
# We'll explore each phase using the example of a **"Customer Churn Prediction System for a Telecommunications Company,"** aiming to identify customers likely to cancel their service for proactive retention efforts.
#
# ### The Machine Learning Lifecycle (MLLC) Explained with Examples: Customer Churn Prediction
#
# The MLLC is a structured, iterative process guiding an ML project from its initial idea through deployment and continuous improvement. It typically involves the following key phases:
#
# ### 1. Problem Definition & Objective Setting
#
# *   **Goal:** Understand *why* an ML model is being built and *what* success looks like, aligning technical goals with business value.
# *   **Explanation:**
#     *   **Business Problem:** The challenge the company faces and its impact.
#     *   **ML Problem:** How ML can address the business problem, specifying the prediction or insight needed.
#     *   **Scope:** What data, customers, or timeframes are included/excluded.
#     *   **Stakeholders:** Individuals or groups affected by or benefiting from the project (e.g., marketing, customer service).
#     *   **Success Metrics:** Objective measurements for technical (model performance) and business (ROI) success, which should be SMART.
# *   **Example (Customer Churn Prediction):**
#     *   **Business Problem:** "Our company experiences a 15% monthly customer churn rate, leading to significant revenue loss from lost subscriptions and acquisition costs for new customers."
#     *   **ML Problem:** "Develop a model to predict which active customers are most likely to churn within the next 30 days."
#     *   **Scope:** Focus on individual mobile plan subscribers in a specific geographical region, excluding business accounts or new customers within their first month of service.
#     *   **Stakeholders:**
#         *   **Marketing Department:** For targeted retention campaigns.
#         *   **Customer Service:** For proactive outreach to at-risk customers.
#         *   **Product Development:** To understand churn-correlated features and improve services.
#         *   **Executive Leadership:** To monitor project ROI and strategic impact.
#     *   **Success Metrics:**
#         *   **Technical:** Achieve a model with at least 75% Precision and 70% Recall for predicting churn on the test set.
#         *   **Business:** Reduce the overall customer churn rate by 10% within 6 months of model deployment, leading to a projected $500,000 increase in monthly recurring revenue.
#
# ### 2. Data Collection & Preparation
#
# *   **Goal:** Acquire, understand, clean, and transform raw data into a suitable format for machine learning, often the most time-consuming phase.
# *   **Explanation:**
#     *   **Collection:** Sourcing data from various internal (databases, logs) and external (APIs) sources.
#     *   **Exploratory Data Analysis (EDA):** Understanding data distributions, variable relationships, patterns, and initial insights.
#     *   **Cleaning:** Handling missing values, outliers, inconsistent formats, and erroneous data.
#     *   **Preprocessing:** Transforming data for model compatibility (e.g., scaling numerical features, encoding categorical features, handling imbalanced datasets).
#     *   **Feature Engineering:** Creating new, more informative features from existing ones to improve model performance.
# *   **Example (Customer Churn Prediction):**
#     *   **Data Collection:**
#         *   **Customer Database:** Age, gender, tenure, plan type, contract dates.
#         *   **Billing System:** Monthly charges, payment history, late payment flags.
#         *   **Usage Data:** Call duration, international calls, data usage, SMS count.
#         *   **Customer Support Logs:** Number of complaints, resolution time, last interaction date.
#         *   **Website/App Activity:** Login frequency, feature usage.
#         *   **Target Variable:** A "churned" flag (1 if customer canceled in last 30 days, 0 otherwise).
#     *   **Exploratory Data Analysis (EDA):**
#         *   Visualize churn rate by `tenure` (e.g., new vs. old customers).
#         *   Plot distribution of `monthly charges` for churned vs. non-churned.
#         *   Check correlations (e.g., `data usage` and `monthly charges`).
#         *   Identify data imbalance (churn customers as minority class).
#     *   **Cleaning:**
#         *   Impute missing `gender` values (e.g., "Unknown" or mode).
#         *   Remove or correct impossible `tenure` values.
#         *   Address outliers in `monthly charges` or `call duration`.
#     *   **Preprocessing:**
#         *   **Scaling:** Apply `StandardScaler` to numerical features (`monthly charges`, `data usage`, `tenure`).
#         *   **Encoding:** Use `OneHotEncoder` for categorical (`plan type`) and `LabelEncoder` for binary (`gender`).
#         *   **Handling Imbalance:** Consider SMOTE or class weights during model training.
#     *   **Feature Engineering:**
#         *   `Tenure_Category`: Bin `tenure` into 'New', 'Mid', 'Long-term'.
#         *   `Avg_Monthly_Usage_Cost`: `Monthly_Charges` / `Data_Usage`.
#         *   `Complaint_Frequency`: Count of complaints in last 90 days.
#         *   `Recent_Interaction_Flag`: Binary flag for recent support interaction.
#
# ### 3. Model Development & Training
#
# *   **Goal:** Select appropriate algorithms, partition data, train the model, and fine-tune its parameters.
# *   **Explanation:**
#     *   **Algorithm Selection:** Choosing the right ML model type (e.g., classification, regression) based on the problem and data.
#     *   **Data Splitting:** Dividing data into training, validation, and test sets for robust evaluation and preventing overfitting.
#     *   **Training:** Feeding training data to the algorithm to learn patterns.
#     *   **Hyperparameter Tuning:** Adjusting model configuration parameters to optimize performance on the validation set.
#     *   **Cross-Validation:** A technique for robust model performance estimation and hyperparameter tuning across multiple data subsets.
# *   **Example (Customer Churn Prediction):**
#     *   **Algorithm Selection:** For binary classification, consider:
#         *   Logistic Regression, Random Forest, Gradient Boosting (XGBoost, LightGBM), Neural Networks.
#     *   **Data Splitting:**
#         *   **Training Set (70-80%):** To train the model.
#         *   **Validation Set (10-15%):** For hyperparameter tuning and model selection.
#         *   **Test Set (10-15%):** Held out for unbiased final evaluation.
#         *   *Crucial:* Use stratified sampling to maintain churn proportion across sets.
#     *   **Training:** Train an XGBoost Classifier on the training data.
#     *   **Hyperparameter Tuning:** Use `GridSearchCV` or `RandomizedSearchCV` with cross-validation on the training + validation set, optimizing for F1-score or ROC AUC due to data imbalance.
#
# ### 4. Model Evaluation
#
# *   **Goal:** Rigorously assess the trained model's performance on unseen data to ensure it meets objectives and generalizes well.
# *   **Explanation:**
#     *   **Performance Metrics:** Using appropriate, task-specific metrics (e.g., for classification: accuracy, precision, recall, F1-score, ROC AUC, Confusion Matrix).
#     *   **Generalization:** Checking for overfitting (good on training, poor on unseen) or underfitting (poor on both).
#     *   **Bias & Fairness:** Analyzing if the model makes unfair or discriminatory predictions toward specific demographic groups.
#     *   **Interpretability:** Understanding *why* the model makes certain predictions, crucial for trust and debugging.
# *   **Example (Customer Churn Prediction):**
#     *   **Performance Metrics (on the held-out Test Set):**
#         *   **Confusion Matrix:** Shows True Positives, False Positives, True Negatives, False Negatives.
#         *   **Precision (of churn predictions):** Percentage of flagged "at risk" customers who *actually* churned (e.g., 78%).
#         *   **Recall (of actual churners):** Percentage of *actual* churners correctly identified by the model (e.g., 72%).
#         *   **F1-Score:** Harmonic mean of precision and recall, useful for imbalanced datasets.
#         *   **ROC AUC:** Measures the model's ability to distinguish churn vs. no-churn across thresholds.
#         *   **Plotting Precision-Recall Curve:** To understand trade-offs at different thresholds.
#     *   **Generalization:** Compare performance metrics between training and test sets; a significant drop in test set performance indicates overfitting.
#     *   **Bias & Fairness:**
#         *   Calculate precision and recall for different demographic groups (e.g., age, gender).
#         *   Check for disproportionate flagging or missing churn in certain groups.
#         *   Utilize tools like AIF360 or Fairlearn for detection and mitigation.
#     *   **Interpretability:** Use SHAP or LIME to understand influential features (e.g., "high data usage to plan ratio," "recent customer service complaints").
#
# ### 5. Model Deployment
#
# *   **Goal:** Integrate the validated model into a production environment, making it available for real-world predictions and actions.
# *   **Explanation:**
#     *   **Integration:** Connecting the model to existing business systems (e.g., CRM, marketing automation).
#     *   **Infrastructure:** Setting up necessary hardware and software to host and run the model.
#     *   **Scalability:** Ensuring the model can handle expected prediction load and grow with demand.
#     *   **Reliability & Latency:** Designing robust, available deployments that provide timely predictions.
#     *   **Deployment Methods:** Real-time APIs, batch processing, edge deployment.
# *   **Example (Customer Churn Prediction):**
#     *   **Deployment Method:**
#         *   **Real-time API:** Wrap the XGBoost model in a REST API (e.g., Flask/FastAPI), deploy to cloud (AWS SageMaker, Azure ML, GCP AI Platform, or Kubernetes). Used by customer service dashboards or websites for immediate churn probability.
#         *   **Batch Prediction:** Schedule daily/weekly jobs to run the model on active customer profiles. Output (churn-prone customers list) ingested by marketing automation for campaigns.
#     *   **Infrastructure:** Deploy Dockerized model and API onto a Kubernetes cluster or use serverless functions (AWS Lambda).
#     *   **Integration:**
#         *   Connect the real-time API to the customer service application.
#         *   Integrate batch prediction output with CRM (Salesforce) and marketing automation (Braze).
#     *   **Scalability & Reliability:** Implement auto-scaling for API, set up load balancers, and ensure redundant deployments.
#
# ### 6. Monitoring & Maintenance
#
# *   **Goal:** Continuous oversight of a deployed model to prevent performance degradation and ensure its relevance to evolving business environments.
# *   **Explanation:**
#     *   **Performance Monitoring:** Tracking key business and technical metrics of the deployed model in real-time.
#     *   **Data Drift:** Detecting changes in the distribution of input data features compared to training data.
#     *   **Concept Drift:** Detecting changes in the relationship between input features and the target variable (underlying patterns are no longer true).
#     *   **Retraining/Updating:** Initiating a new MLLC cycle when performance degrades, drift is detected, or new data is available.
#     *   **A/B Testing:** Comparing new model versions against the current production model.
# *   **Example (Customer Churn Prediction):**
#     *   **Performance Monitoring:**
#         *   **Business Metrics:** Track actual churn rate of "high risk" vs. "low risk" customers, retention campaign conversion rate.
#         *   **Model Metrics:** Continuously track precision, recall, F1-score on actual outcomes.
#         *   **Dashboards:** Create custom dashboards (Grafana, Tableau) to visualize metrics over time; set alerts for performance drops.
#     *   **Data Drift Detection:**
#         *   Monitor distributions of key input features (`average monthly call duration`, `data usage`, `monthly charges`) in production.
#         *   *Scenario:* New unlimited data plan changes `data usage` patterns, causing inaccurate predictions.
#         *   Tools: Evidently AI or deepchecks can automate this.
#     *   **Concept Drift Detection:**
#         *   Observe if model accuracy decreases even with stable input data distributions.
#         *   *Scenario:* A major competitor introduces a disruptive service, changing customer loyalty drivers.
#         *   Monitor residual errors or prediction confidence over time.
#     *   **Retraining & Updating:**
#         *   **Scheduled Retraining:** Automatically retrain the model quarterly using the latest data.
#         *   **Triggered Retraining:** If significant data drift or performance degradation is detected, trigger immediate retraining (may involve new data types).
#         *   **A/B Testing:** Before full deployment, run A/B tests to compare a new model version against the current production model to confirm improvement.
#
# ### The Iterative Nature: Looping Back for Continuous Improvement
#
# *   The MLLC is inherently **iterative**; insights from later stages frequently lead back to earlier ones.
# *   This continuous feedback loop is vital for adapting to changing data, business requirements, and improving model effectiveness.
# *   **Example (Customer Churn Prediction):**
#     *   If **monitoring (Phase 6)** reveals **data drift**, it might lead back to **data collection & preparation (Phase 2)** to include new sources or **feature engineering (Phase 2)**.
#     *   If **model evaluation (Phase 4)** uncovers **bias**, it might necessitate revisiting **data collection & preparation (Phase 2)** for representative data, trying different **algorithms (Phase 3)**, or refining **problem definition (Phase 1)**.
#     *   If initial **business objectives (Phase 1)** are not met, it could prompt a re-evaluation of the entire approach, leading to new data, different model types, or a revised understanding of the problem.
# *   This iterative nature ensures ML projects are dynamic, responsive, and continuously optimized to deliver maximum business value.

# %%
def advanced_rag(query):
    context = retrieve(query, k=3)

    prompt = f"""
    Use ONLY this context to answer:

    {context}

    Question: {query}
    """

    return model.generate_content(prompt).text

print(advanced_rag("What is reinforcement learning?"))
# Out:
# Reinforcement learning uses rewards.

# %%
def guarded_agent(query):
    prompt = f"""
    Answer ONLY in JSON format:
    {{
        "answer": "",
        "confidence": ""
    }}

    Question: {query}
    """

    return model.generate_content(prompt).text

print(guarded_agent("Explain AI"))
# Out:
# ```json
# {
#     "answer": "Artificial intelligence (AI) is a broad field of computer science that aims to create machines capable of performing tasks that typically require human intelligence. This includes learning, problem-solving, decision-making, understanding language, recognizing patterns, and perceiving the environment. AI systems are designed to process information, identify patterns, and make predictions or take actions, often improving their performance over time through experience (machine learning). Key subfields include machine learning, deep learning, natural language processing, computer vision, and robotics.",
#     "confidence": "1.0"
# }
# ```

# %%
def autonomous_agent(goal, max_steps=3):
    current_state = goal

    for step in range(max_steps):
        print(f"\nStep {step+1}")

        thought = model.generate_content(
            f"What should be done next for: {current_state}"
        ).text

        print("Thought:", thought)

        current_state = thought

    return current_state

autonomous_agent("Build AI project")
# Out:
# Step 1
# Thought: That's a fantastic goal! "Build an AI project" is a broad statement, so the "next step" heavily depends on where you currently are in the process.
#
# Let's break it down based on common stages. **Choose the section that best describes your current situation:**
#
# ---
#
# ### **If you're just starting and have an idea (or no idea yet):**
#
# This is the most common starting point. Your next steps should focus on defining and validating your concept.
#
# 1.  **Define the Problem & Use Case Clearly:**
#     *   **What problem are you trying to solve?** (e.g., "Customers complain about slow response times," "I want to predict stock prices," "I want to classify images of pets.")
#     *   **Who has this problem?** (Your target users/stakeholders.)
#     *   **Why is AI the solution?** (Could a simpler, non-AI solution work better/cheaper?)
#     *   **What is the desired outcome or impact?** (e.g., "Reduce customer wait time by 50%," "Increase prediction accuracy to 85%," "Automatically tag pet photos.")
#     *   **Be specific!** "Build a chatbot" isn't a problem; "Reduce the number of common support queries handled by human agents by 30% through an automated chatbot" is much better.
#
# 2.  **Research & Feasibility Assessment:**
#     *   **Is this technically feasible with current AI capabilities?** (e.g., predicting the exact lottery numbers might not be feasible, but predicting trending numbers might be.)
#     *   **Are there existing solutions or similar projects?** (Learn from them, don't reinvent the wheel unless you have a novel approach.)
#     *   **What data would you need?** (Crucial for AI.) Can you access or generate this data? What's its quality like?
#     *   **What resources are required?** (Time, budget, computational power, expertise.)
#
# 3.  **Set SMART Goals:**
#     *   **S**pecific: What exactly will the AI do?
#     *   **M**easurable: How will you quantify success? (e.g., 90% accuracy, 2-second response time.)
#     *   **A**chievable: Is it realistic given your resources?
#     *   **R**elevant: Does it align with your overall objectives?
#     *   **T**ime-bound: When do you expect to achieve certain milestones?
#
# 4.  **Consider Ethical Implications (Early!):**
#     *   Could your AI be biased?
#     *   What are the privacy implications of the data you'll use?
#     *   How will you ensure fairness and transparency?
#
# ---
#
# ### **If you have a clear problem defined and are ready to plan:**
#
# You've got your "what" and "why." Now focus on the "how."
#
# 1.  **Data Strategy:**
#     *   **Identify specific data sources:** Where will you get the data (internal databases, public datasets, web scraping, manual collection)?
#     *   **Plan data collection/acquisition:** How will you get it? What tools will you use?
#     *   **Estimate data volume and quality:** Is there enough? Is it clean?
#     *   **Plan for data annotation/labeling (if needed):** How will you get the "answers" for your AI to learn from? (e.g., tagging images, transcribing audio, classifying text.)
#
# 2.  **Choose Your AI Approach/Model:**
#     *   **What type of AI?** (Machine Learning, Deep Learning, NLP, Computer Vision, Reinforcement Learning?)
#     *   **Which algorithms/models are suitable?** (e.g., Linear Regression, Random Forest, CNN, Transformer models like BERT, OpenAI's GPT series). This might involve some initial research and experimentation.
#     *   **Consider pre-trained models or APIs:** Can you leverage existing solutions (e.g., Google Cloud Vision API, Hugging Face models, OpenAI API) rather than building from scratch?
#
# 3.  **Outline Technical Architecture:**
#     *   **What infrastructure will you need?** (Cloud platforms like AWS, GCP, Azure; on-premise servers.)
#     *   **How will the different components interact?** (Data ingestion pipeline, training environment, inference API, user interface.)
#     *   **What programming languages and frameworks?** (Python with TensorFlow/PyTorch/Scikit-learn is common.)
#
# 4.  **Define Evaluation Metrics:**
#     *   **How will you measure the performance of your AI model?** (e.g., accuracy, precision, recall, F1-score, RMSE, BLEU score, latency.) These should align with your SMART goals.
#
# 5.  **Project Plan & Milestones:**
#     *   Break the project down into smaller, manageable tasks.
#     *   Assign responsibilities if you're working with a team.
#     *   Set timelines for each phase (data collection, model training, deployment).
#
# ---
#
# ### **If you're already in the development phase (e.g., you have a model, but it's not deployed):**
#
# You've built something, now make it useful.
#
# 1.  **Refine and Optimize Your Model:**
#     *   **Hyperparameter tuning:** Get the best performance out of your chosen model.
#     *   **Feature engineering:** Improve the input data to help the model learn better.
#     *   **Error analysis:** Understand *why* your model makes mistakes and address those specific issues.
#     *   **Regularization techniques:** Prevent overfitting.
#
# 2.  **Prepare for Deployment (MLOps principles):**
#     *   **Version control:** Track your code, data, and models.
#     *   **Containerization:** Package your model and dependencies (e.g., Docker) for consistent deployment.
#     *   **API development:** Create an interface for other applications to interact with your model (e.g., Flask, FastAPI).
#
# 3.  **Build a User Interface (if applicable):**
#     *   How will users interact with your AI? (Web app, mobile app, command-line tool, integration into existing software.)
#
# 4.  **Testing:**
#     *   **Unit tests:** For individual functions.
#     *   **Integration tests:** How components work together.
#     *   **Performance tests:** How fast and scalable is your solution?
#     *   **Bias tests:** Ensure fairness across different demographic groups if relevant.
#
# 5.  **Documentation:**
#     *   Document your code, data pipelines, model architecture, and deployment procedures.
#
# ---
#
# ### **General Advice for ANY Stage:**
#
# *   **Start Small & Iterate:** Don't try to build the perfect, most complex AI first. Start with a Minimum Viable Product (MVP) and improve it over time.
# *   **Stay Flexible:** AI projects often involve unexpected challenges. Be prepared to pivot or adjust your approach.
# *   **Learn Continuously:** The field of AI is rapidly evolving. Keep learning new techniques, tools, and best practices.
# *   **Collaborate:** If possible, work with others or seek advice from experienced AI practitioners.
#
# ---
#
# **To give you the most specific "next step," tell me:**
#
# *   **What is the core idea or problem you want to solve with AI?**
# *   **What have you done so far?** (e.g., "I have an idea, but no plan," "I've collected some data," "I've trained a basic model.")
#
# Step 2
# Thought: This is an excellent, detailed breakdown!
#
# To give you the most specific "next step" from this fantastic guide, I need a little more information from you.
#
# **Please tell me:**
#
# *   **What is the core idea or problem you want to solve with AI?**
# *   **What have you done so far?** (e.g., "I have an idea, but no plan," "I've collected some data," "I've trained a basic model.")
#
# Once I have that, I can point you directly to the relevant section and highlight your immediate next action!
#
# Step 3
# Thought: Okay, this is great! To answer your questions so you can point me in the right direction:
#
# *   **What is the core idea or problem you want to solve with AI?**
#     We want to leverage AI to significantly improve the efficiency and consistency of content creation for our marketing department. Specifically, we're looking to automate the summarization of long-form articles (e.g., blog posts, research papers) into concise snippets suitable for social media posts, and to generate initial outlines or draft paragraphs for new blog posts based on given topics and keywords. The core problem is the time-consuming manual process and the occasional inconsistency in tone/style across different content creators.
#
# *   **What have you done so far?**
#     We've had several internal discussions and stakeholder meetings. We've clearly defined the problem, identified the target users (our marketing team), and mapped out the desired outputs (social media snippets, blog outlines/drafts). We've also done some preliminary research into existing tools and techniques. However, we haven't formally gathered any data sets, selected specific AI models, or started any technical development. We're currently in the "planning and strategy" phase, trying to translate our high-level vision into actionable steps and identify the necessary resources and tools.
#
# Based on that, what would be the very next actionable step from the guide you provided?
# 'Okay, this is great! To answer your questions so you can point me in the right direction:\n\n*   **What is the core idea or problem you want to solve with AI?**\n    We want to leverage AI to significantly improve the efficiency and consistency of content creation for our marketing department. Specifically, we\'re looking to automate the summarization of long-form articles (e.g., blog posts, research papers) into concise snippets suitable for social media posts, and to generate initial outlines or draft paragraphs for new blog posts based on given topics and keywords. The core problem is the time-consuming manual process and the occasional inconsistency in tone/style across different content creators.\n\n*   **What have you done so far?**\n    We\'ve had several internal discussions and stakeholder meetings. We\'ve clearly defined the problem, identified the target users (our marketing team), and mapped out the desired outputs (social media snippets, blog outlines/drafts). We\'ve also done some preliminary research into existing tools and techniques. However, we haven\'t formally gathered any data sets, selected specific AI models, or started any technical development. We\'re currently in the "planning and strategy" phase, trying to translate our high-level vision into actionable steps and identify the necessary resources and tools.\n\nBased on that, what would be the very next actionable step from the guide you provided?'

# %%
def manager_agent(task):
    plan = planner_agent(task)

    steps = plan.split("\n")

    results = []

    for step in steps:
        if step.strip():
            result = executor_agent(step)
            results.append(result)

    return results

print(manager_agent("Learn Python for data science"))

# %%
def final_ai_system(query):
    context = retrieve(query)

    plan = planner_agent(query)

    execution = executor_agent(plan)

    review = critic_agent(execution)

    return {
        "context": context,
        "plan": plan,
        "execution": execution,
        "final_answer": review
    }

print(final_ai_system("How to become a data scientist?"))
